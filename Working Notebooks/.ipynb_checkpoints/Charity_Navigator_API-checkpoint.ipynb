# %%
import json 
import requests
import numpy as np
import pandas as pd
import time 
import random
from bs4 import BeautifulSoup as BS

# %%
#import the api id and api key
from keys import app_id, app_key
app_key
# Out:
# '15c0fd55e8a27aa023c8391cf56e3300'

# %%
#getting states abbreviations
url='https://www23.statcan.gc.ca/imdb/p3VD.pl?Function=getVD&TVD=53971'

page = requests.get(url)
bs = BS(page.content, 'html.parser')
states = pd.DataFrame([[i.text for i in x.findAll('td')] for x in bs.table.findAll('tr')][1:])[2].unique()

# %%
states
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
#setting url
data, badlist = [] ,[]
for state in states:
    for page in range(1,100):
        url = f'https://api.data.charitynavigator.org/v2/Organizations?app_id=e890d85f&app_key=15c0fd55e8a27aa023c8391cf56e3300&state={state}&pageSize=1000&pageNum={page}'
        response = requests.get(url)
        if response.status_code == 200:
            polls = response.json()
            for x in polls:
                try:
                    lst = []
                    lst.append(x['mission'])
                    lst.append(x['tagLine'])
                    lst.append(x['charityName'])
                    lst.append(x['category']['categoryName'])
                    lst.append(x['category']['categoryID'])
                    lst.append(x['cause']['causeName'])
                    lst.append(x['cause']['causeID'])
                    lst.append(x['mailingAddress']['city'])
                    lst.append(x['mailingAddress']['stateOrProvince'])
                    lst.append(x['mailingAddress']['postalCode'])
                    lst.append(x['currentRating']['score'])
                    lst.append(x['currentRating']['rating'])
                    lst.append(x['advisories']['severity'])
                    current_accountability_rating = x['currentRating']['accountabilityRating']
                    lst.append(current_accountability_rating['score'])
                    lst.append(current_accountability_rating['rating'])
                    lst.append(x['irsClassification']['nteeType'])
                    lst.append(x['irsClassification']['classification'])
                    lst.append(x['irsClassification']['affiliation'])
                    lst.append(x['irsClassification']['foundationStatus'])
                    lst.append(x['irsClassification']['nteeClassification'])
                    lst.append(x['irsClassification']['deductibility'])
                    lst.append(x['irsClassification']['subsection'])
                    lst.append(x['irsClassification']['assetAmount'])
                    lst.append(x['irsClassification']['incomeAmount'])
                    current_financial_rating = x['currentRating']['financialRating']
                    lst.append(current_financial_rating['score'])
                    lst.append(current_financial_rating['rating'])
                    data.append(lst)
                except:
                    badlist.append(x)
        else:
            print(state, page)
            break
        time.sleep(random.choice([x/10 for x in range(7,13)]))
    df = pd.DataFrame(data)
    df.to_csv('data.csv')
# Out:
# AL 11
# AK 7
# AZ 11
# AR 11
# CA 11
# CO 11
# CT 11
# DE 9
# DC 11
# FL 11
# GA 11
# HI 10
# ID 11
# IL 11
# IN 11
# IA 11
# KS 11
# KY 11
# LA 11
# ME 11
# MD 11
# MA 11
# MI 11
# MN 11
# MS 11
# MO 11
# MT 11
# NE 11
# NV 11
# NH 10
# NJ 11
# NM 11
# NY 11
# NC 11
# ND 7
# OH 11
# OK 11
# OR 11
# PA 11
# RI 10
# SC 11
# SD 8
# TN 11
# TX 11
# UT 11
# VT 8
# VA 11
# WA 11
# WV 11
# WI 11
# WY 7

# %%
mission = x['mission']
tagline = x['tagLine']
name = x['charityName']
category_name = x['category']['categoryName']
category_ID = x['category']['categoryID']
cause_name = x['cause']['causeName']
cause_ID = x['cause']['causeID']
city = x['mailingAddress']['city']
state = x['mailingAddress']['stateOrProvince']
zipcode = x['mailingAddress']['postalCode']
current_score = x['currentRating']['score']
current_rating = x['currentRating']['rating']
advisories = x['advisories']['severity']
current_accountability_rating = x['currentRating']['accountabilityRating']
accountability_score = current_accountability_rating['score']
accountability_rating = current_accountability_rating['rating']

# %%
mission = x['mission']
tagline = x['tagLine']
name = x['charityName']
category_name = x['category']['categoryName']
category_ID = x['category']['categoryID']
cause_name = x['cause']['causeName']
cause_ID = x['cause']['causeID']
city = x['mailingAddress']['city']
state = x['mailingAddress']['stateOrProvince']
zipcode = x['mailingAddress']['postalCode']
current_score = x['currentRating']['score']
current_rating = x['currentRating']['rating']
advisories = x['advisories']['severity']
current_accountability_rating = x['currentRating']['accountabilityRating']
accountability_score = current_accountability_rating['score']
accountability_rating = current_accountability_rating['rating']
irs_org_type = x['irsClassification']['nteeType']
irs_classification = x['irsClassification']['classification']
npo_affilitation = x['irsClassification']['affiliation']
foundation_status = x['irsClassification']['foundationStatus']
irs_org_classification = x['irsClassification']['nteeClassification']
tax_deductibility = x['irsClassification']['deductibility']
npo_status = x['irsClassification']['subsection']
org_assets = x['irsClassification']['assetAmount']
org_income = x['irsClassification']['incomeAmount']
current_financial_rating = x['currentRating']['financialRating']
fin_score = current_financial_rating['score']
fin_rating = current_financial_rating['rating']

# %%
df.shape
# Out:
# (2550, 26)

# %%
len(badlist)
# Out:
# 479409

# %%
badlist[0]
# Out:
# {'charityNavigatorURL': 'https://www.charitynavigator.org/?bay=search.profile&ein=010520599&utm_source=DataAPI&utm_content=03ccde74',
#  'mission': None,
#  'websiteURL': None,
#  'tagLine': None,
#  'charityName': 'BLUE KNIGHTS MOTORCYCLE CLUB',
#  'ein': '010520599',
#  'orgID': None,
#  'irsClassification': {'deductibility': 'Contributions are not deductible',
#   'subsection': '501(c)(10)',
#   'assetAmount': 0,
#   'nteeType': 'Mutual/Membership Benefit Organizations, Other',
#   'nteeSuffix': None,
#   'incomeAmount': 0,
#   'filingRequirement': '990 - Required to file Form 990-N - Income less than $50,000 per year',
#   'classification': 'Domestic Fraternal Societies and Associations',
#   'latest990': 'December, 2019',
#   'rulingDate': 'February, 2014',
#   'nteeCode': 'Y42',
#   'groupName': None,
#   'affiliation': 'Independent - the organization is an independent organization or an independent auxiliary (i.e., not affiliated with a National, Regional, or Geographic grouping of organizations).',
#   'deductibilityCode': '2',
#   'foundationStatus': 'All organizations except 501(c)(3)',
#   'nteeClassification': 'Domestic Fraternal Societies',
#   'accountingPeriod': 'December',
#   'exemptOrgStatusCode': '01',
#   'exemptOrgStatus': 'Unconditional Exemption',
#   'deductibilityDetail': None,
#   'nteeLetter': 'Y'},
#  'mailingAddress': {'country': None,
#   'stateOrProvince': 'AL',
#   'city': 'FAIRHOPE',
#   'postalCode': '36532-2923',
#   'streetAddress1': '319 N INGLESIDE ST',
#   'streetAddress2': None},
#  'advisories': {'severity': None,
#   'active': {'_rapid_links': {'related': {'href': 'https://api.data.charitynavigator.org/v2/Organizations/010520599/Advisories?status=ACTIVE'}}}},
#  'organization': {'charityName': 'BLUE KNIGHTS MOTORCYCLE CLUB',
#   'ein': '010520599',
#   'charityNavigatorURL': 'https://www.charitynavigator.org/?bay=search.profile&ein=010520599&utm_source=DataAPI&utm_content=03ccde74',
#   '_rapid_links': {'related': {'href': 'https://api.data.charitynavigator.org/v2/Organizations/010520599'}}}}

# %%
data[0]
# Out:
# ["Impact Alabama was founded in 2004 as the state's first nonprofit dedicated to developing substantive service-learning and leadership development projects for college students and recent college graduates. Growing from a team of five in 2004 to more than fifty in 2014, we have quickly grown into the premier nonprofit destination for high-achieving students and graduates to make a difference in their communities. After serving hundreds of thousands of families in all sixty-seven counties in Alabama, we've made the decision to expand Impact Alabama to other states and communities. Impact America was formed in 2014 with the mission to engage a generation for change.",
#  'Engaging a Generation for Change.',
#  'Impact America',
#  'Human Services',
#  6,
#  'Social Services',
#  29,
#  'Birmingham',
#  'AL',
#  '35209',
#  85.98,
#  3,
#  None,
#  82,
#  3,
#  'Educational Institutions and Related Activities',
#  'Educational Organization',
#  'Independent - the organization is an independent organization or an independent auxiliary (i.e., not affiliated with a National, Regional, or Geographic grouping of organizations).',
#  'Organization which receives a substantial part of its support from a governmental unit or the general public\xa0\xa0 170(b)(1)(A)(vi)',
#  'Student Services, Organizations of Students',
#  'Contributions are deductible',
#  '501(c)(3)',
#  2032739,
#  3364323,
#  91.7,
#  4]

# %%
df.head()
# Out:
#                                                   0   \
# 0  Impact Alabama was founded in 2004 as the stat...
# 1  Four Corners Ministries exists to communicate ...
# 2  The Mobile Symphony Orchestra enhances lives b...
# 3  Big Oak Ranch is a Christian home for children...
# 4  The Community Foundation of Greater Huntsville...
#
#                                                   1   \
# 0                  Engaging a Generation for Change.
# 1                                    The Gospel Sent
# 2  Working to create an environment that allows f...
# 3     A Christian home for children needing a chance
# 4                              A Smart Place to Give
#
#                                            2                          3   4   \
# 0                              Impact America             Human Services   6
# 1                     Four Corners Ministries                   Religion   9
# 2                   Mobile Symphony Orchestra  Arts, Culture, Humanities   2
# 3                               Big Oak Ranch             Human Services   6
# 4  Community Foundation of Greater Huntsville      Community Development  10
#
#                                                 5   6            7   8   \
# 0                                  Social Services  29   Birmingham  AL
# 1                             Religious Activities  26      Opelika  AL
# 2                                  Performing Arts   4       Mobile  AL
# 3  Youth Development, Shelter, and Crisis Services  16  Springville  AL
# 4                            Community Foundations  22   Huntsville  AL
#
#       9   ...                        16  \
# 0  35209  ...  Educational Organization
# 1  36801  ...   Charitable Organization
# 2  36602  ...  Educational Organization
# 3  35146  ...   Charitable Organization
# 4  35801  ...   Charitable Organization
#
#                                                   17  \
# 0  Independent - the organization is an independe...
# 1  Independent - the organization is an independe...
# 2  Independent - the organization is an independe...
# 3  Independent - the organization is an independe...
# 4  Independent - the organization is an independe...
#
#                                                   18  \
# 0  Organization which receives a substantial part...
# 1  Organization that normally receives no more th...
# 2  Organization that normally receives no more th...
# 3  Organization which receives a substantial part...
# 4  Organization which receives a substantial part...
#
#                                             19                            20  \
# 0  Student Services, Organizations of Students  Contributions are deductible
# 1                                    Christian  Contributions are deductible
# 2                          Symphony Orchestras  Contributions are deductible
# 3                       Group Home (Long Term)  Contributions are deductible
# 4                        Community Foundations  Contributions are deductible
#
#           21          22          23     24 25
# 0  501(c)(3)   2032739.0   3364323.0  91.70  4
# 1  501(c)(3)   2602296.0   1930948.0  96.10  4
# 2  501(c)(3)   1162334.0   1597054.0  66.45  1
# 3  501(c)(3)  49861768.0  22928887.0  99.11  4
# 4  501(c)(3)  25229948.0  12989927.0  95.00  4
#
# [5 rows x 26 columns]

# %%
df2 = pd.DataFrame(badlist)
df2.to_csv('badlist.csv')

# %%
df2.head()
# Out:
#                                  charityNavigatorURL mission websiteURL  \
# 0  https://www.charitynavigator.org/?bay=search.p...    None       None
# 1  https://www.charitynavigator.org/?bay=search.p...    None       None
# 2  https://www.charitynavigator.org/?bay=search.p...    None       None
# 3  https://www.charitynavigator.org/?bay=search.p...    None       None
# 4  https://www.charitynavigator.org/?bay=search.p...    None       None
#
#   tagLine                             charityName        ein orgID  \
# 0    None            BLUE KNIGHTS MOTORCYCLE CLUB  010520599  None
# 1    None            New Hope Outreach Ministries  010550415  None
# 2    None  Health and Wellness Educational Center  010550656  None
# 3    None                    Mark Howard Cemetery  010552873  None
# 4    None          Thurber Family Foundation Inc.  010553690  None
#
#                                    irsClassification  \
# 0  {'deductibility': 'Contributions are not deduc...
# 1  {'deductibility': 'Contributions are deductibl...
# 2  {'deductibility': 'Contributions are deductibl...
# 3  {'deductibility': 'Contributions are deductibl...
# 4  {'deductibility': 'Contributions are deductibl...
#
#                                       mailingAddress  \
# 0  {'country': None, 'stateOrProvince': 'AL', 'ci...
# 1  {'country': None, 'stateOrProvince': 'AL', 'ci...
# 2  {'country': None, 'stateOrProvince': 'AL', 'ci...
# 3  {'country': None, 'stateOrProvince': 'AL', 'ci...
# 4  {'country': None, 'stateOrProvince': 'AL', 'ci...
#
#                                           advisories  \
# 0  {'severity': None, 'active': {'_rapid_links': ...
# 1  {'severity': None, 'active': {'_rapid_links': ...
# 2  {'severity': None, 'active': {'_rapid_links': ...
# 3  {'severity': None, 'active': {'_rapid_links': ...
# 4  {'severity': None, 'active': {'_rapid_links': ...
#
#                                         organization currentRating
# 0  {'charityName': 'BLUE KNIGHTS MOTORCYCLE CLUB'...           NaN
# 1  {'charityName': 'New Hope Outreach Ministries'...           NaN
# 2  {'charityName': 'Health and Wellness Education...           NaN
# 3  {'charityName': 'Mark Howard Cemetery', 'ein':...           NaN
# 4  {'charityName': 'Thurber Family Foundation Inc...           NaN

# %%
df2.shape
# Out:
# (479409, 12)
